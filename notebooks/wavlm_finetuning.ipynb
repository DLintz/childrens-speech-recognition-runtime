# %%
import os

# Mudar para o diretório onde está o arquivo
novo_diretorio = "/Users/daltonlintz/Desktop/Competicoes/DD_MS_-_Childrens_Speech_Recognition_Challenge_-_Phonetic_Track/childrens-speech-recognition-runtime/notebooks"
os.chdir(novo_diretorio)

print(f"✅ Diretório alterado para: {os.getcwd()}")
print(f"📄 Arquivos .py agora: {[f for f in os.listdir('.') if f.endswith('.py')]}")

from wavlm_finetuning import train_wavlm

trainer, model, processor = train_wavlm()
# Out:
# ✅ Diretório alterado para: /Users/daltonlintz/Desktop/Competicoes/DD_MS_-_Childrens_Speech_Recognition_Challenge_-_Phonetic_Track/childrens-speech-recognition-runtime/notebooks
# 📄 Arquivos .py agora: ['wavlm_finetuning.py', 'preprocessing_pipeline.py']
# ...
# 🎯 FASE 3: FINE-TUNING WavLM BASE+
# ...
#
# 📂 Carregando splits...
#    Treino: 13325 amostras
#    Validação: 1484 amostras
#
# 🔤 Configurando tokenizer IPA...
#
# 📦 Criando datasets...
#
# 🤖 Carregando WavLM Base+...
# You are using a model of type `wavlm` to instantiate a model of type `wav2vec2`. This may be expected if you are loading a checkpoint that shares a subset of the architecture (e.g., loading a `sam2_video` checkpoint into `Sam2Model`), but is otherwise not supported and can yield errors. Please verify that the checkpoint is compatible with the model you are instantiating.
# Loading weights:   0%|          | 0/211 [00:00<?, ?it/s]
# Wav2Vec2ForCTC LOAD REPORT from: microsoft/wavlm-base-plus
# ...
